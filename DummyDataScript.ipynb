# %%
for i in range(1,50):
  print "('BTC',",24000*i,",",695000*i,"),('ETH',",2000*i,",",695000*i,"),('XRP',",2000*i,",",695000*i,"),('BCH',",20000*i,",",695000*i,"),('LTC',",25000*i,",",695000*i,"),",
# Out:
# ('BTC', 24000 , 695000 ),('ETH', 2000 , 695000 ),('XRP', 2000 , 695000 ),('BCH', 20000 , 695000 ),('LTC', 25000 , 695000 ), ('BTC', 48000 , 1390000 ),('ETH', 4000 , 1390000 ),('XRP', 4000 , 1390000 ),('BCH', 40000 , 1390000 ),('LTC', 50000 , 1390000 ), ('BTC', 72000 , 2085000 ),('ETH', 6000 , 2085000 ),('XRP', 6000 , 2085000 ),('BCH', 60000 , 2085000 ),('LTC', 75000 , 2085000 ), ('BTC', 96000 , 2780000 ),('ETH', 8000 , 2780000 ),('XRP', 8000 , 2780000 ),('BCH', 80000 , 2780000 ),('LTC', 100000 , 2780000 ), ('BTC', 120000 , 3475000 ),('ETH', 10000 , 3475000 ),('XRP', 10000 , 3475000 ),('BCH', 100000 , 3475000 ),('LTC', 125000 , 3475000 ), ('BTC', 144000 , 4170000 ),('ETH', 12000 , 4170000 ),('XRP', 12000 , 4170000 ),('BCH', 120000 , 4170000 ),('LTC', 150000 , 4170000 ), ('BTC', 168000 , 4865000 ),('ETH', 14000 , 4865000 ),('XRP', 14000 , 4865000 ),('BCH', 140000 , 4865000 ),('LTC', 175000 , 4865000 ), ('BTC', 192000 , 5560000 ),('ETH', 16000 , 5560000 ),('XRP', 16000 , 5560000 ),('BCH
# ...
