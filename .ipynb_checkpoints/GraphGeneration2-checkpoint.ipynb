# %%
#save the json data into text file
from flask import Flask
from flask import request
import requests
import json
from flask import render_template
import psycopg2

import time
from datetime import datetime

# %%
#first close the localhost window then interrupt kernel
app = Flask(__name__)
@app.route('/', methods=['GET','POST'])
def hello():
	return 'Hey'
@app.route('/cryptoPrice',methods=['GET','POST'])
def cryptoPrice():
    cryptoS=raw_input()
    cryptoT=raw_input()
    url = "https://min-api.cryptocompare.com/data/price?fsym={}&tsyms={}".format(cryptoS,cryptoT)
    try:
        response=requests.get(url)
        return response.text
    except:
        return "Connection Error"
#if (__name__ == "__main__"):
#    app.run(debug=False)

# %%
@app.route('/PerHalfHour',methods=['GET','POST'])
def PerHalfHour():
    hostname = 'baasu.db.elephantsql.com'
    username = 'dbuzkqmi'
    password = 'vi24qSFc5TG77k5GPa4aQr3XlnLOBIRf'
    database = 'dbuzkqmi'
    port='5432'
    conn = psycopg2.connect(host=hostname, user=username, password=password, dbname=database,port=port)
    #conn=connection()
    curr=conn.cursor()
    password ='12345'
    email='goyalakshita@gmail.com'
    name='Akshita'
    curr.execute("insert into public.user (password,email,name) values('{}','{}','{}')".format(password,email,name))
    #conn.commit()
    #conn.close()
    cur=conn.cursor()
    cur.execute("select symbol,price_usd,last_updated from public.dummy;")
    rows=cur.fetchall()

    #print (datetime.fromtimestamp(data['Data'][item]['time'])).strftime('%Y-%m-%d %H:%M:%S')
    #listcurr=[]
    for i in range(len(rows)):
        tupl= rows[i]
        var= tupl[2]
        if type(var)==float:
            print i,tupl[0],tupl[1],tupl[2]
        
            #datetime.fromtimestamp(var).strftime('%Y-%m-%d %H:%M:%S')
        #print i,type(var)
        #time.sleep(2)
    return "running in background"
    
        

    
    
    
    
    
    
    
    
    
    """from
    cryptoS=raw_input()
    #to what 
    cryptoT=raw_input()
    #limiting the number of rows
    limit=raw_input()
    #aggregate over what time,1=1 minute,3=3min
    agg=raw_input()
    #for 30 min aggregate of a day limit=48,aggregate=30
    url = "https://min-api.cryptocompare.com/data/histominute?fsym={}&tsym={}&limit={}&aggregate={}&e=CCCAGG".format(cryptoS,cryptoT,limit,agg)
    try:
        response=requests.get(url)
        with open(cryptoS+".json","wb") as fo:
           fo.write(response.text)
        return response.text
    except:
        return "Connection Error"""" """

# %%
import pygal
import json
from datetime import datetime
import time

# %%
@app.route('/BTCDayGraph',methods=['GET','POST'])
def BTCDay():
    cur.execute("select symbol,price_usd,last_updated from public.dummy where symbol='BTC';")
    rows=cur.fetchall()
    BTCd_x_axis_data=[]
    BTCd_y_axis_data=[]
    for i in range(len(rows)-48,len(rows)):
        tupl= rows[i]
        var= tupl[2]
        if type(var)==float:
            BTCd_x_axis_data.append(tupl[2])
            BTCd_y_axis_data.append(tupl[1])
            print tupl[2],tupl[1]
    #conn.close()
    chart=pygal.Line(x_label_rotation=45)
    chart.x_labels=BTCd_x_axis_data
    chart.add('BTC DAY',BTCd_y_axis_data)
    chart=chart.render_data_uri()
    return render_template( 'charts.html', chart = chart)

# %%
@app.route('/ETHDayGraph',methods=['GET','POST'])
def ETHDay():
    
    cur.execute("select symbol,price_usd,last_updated from public.dummy where symbol='ETH';")
    rows=cur.fetchall()
    ETHd_x_axis_data=[]
    ETHd_y_axis_data=[]
    for i in range(len(rows)-48,len(rows)):
        tupl= rows[i]
        var= tupl[2]
        if type(var)==float:
            ETHd_x_axis_data.append(tupl[2])
            ETHd_y_axis_data.append(tupl[1])
            print tupl[2],tupl[1]
    #conn.close()
    chart=pygal.Line(x_label_rotation=45)
    chart.x_labels=ETHd_x_axis_data
    chart.add('ETH DAY',ETHd_y_axis_data)
    chart=chart.render_data_uri()
    return render_template( 'charts.html', chart = chart)

# %%
@app.route('/XRPDayGraph',methods=['GET','POST'])
def XRPDay():
    cur.execute("select symbol,price_usd,last_updated from public.dummy where symbol='XRP';")
    rows=cur.fetchall()
    XRPd_x_axis_data=[]
    XRPd_y_axis_data=[]
    for i in range(len(rows)-48,len(rows)):
        tupl= rows[i]
        var= tupl[2]
        if type(var)==float:
            XRPd_x_axis_data.append(tupl[2])
            XRPd_y_axis_data.append(tupl[1])
            print tupl[2],tupl[1]
    #conn.close()
    chart=pygal.Line(x_label_rotation=45)
    chart.x_labels=XRPd_x_axis_data
    chart.add('XRP DAY',XRPd_y_axis_data)
    chart=chart.render_data_uri()
    return render_template( 'charts.html', chart = chart)

# %%
@app.route("/AllGraphs",methods=['GET','POST'])
def LineGraph():
    curr.execute("select symbol,price_usd,last_updated from public.dummy;")
    rows=curr.fetchall()
    curr0_x_axis_data=[]
    curr0_y_axis_data=[]
    curr1_x_axis_data=[]
    curr1_y_axis_data=[]
    curr2_x_axis_data=[]
    curr2_y_axis_data=[]
    curr3_x_axis_data=[]
    curr3_y_axis_data=[]
    curr4_x_axis_data=[]
    curr4_y_axis_data=[]
    day=len(rows)-46
    record=(rows[day])
    curr0=record[0]
    day=day-1 # -1 leads to rem 4
    record=(rows[day])
    curr4=record[0]
    day=day-1
    record=(rows[day])
    curr3=record[0]
    day=day-1
    record=(rows[day])
    curr2=record[0]
    day=day-1
    record=(rows[day])
    curr1=record[0]
    print(curr0,curr1,curr2,curr3,curr4)
    charts_individual_0=pygal.Line(x_label_rotation=45)
    charts_individual_1=pygal.Line(x_label_rotation=45)
    charts_individual_2=pygal.Line(x_label_rotation=45)
    charts_individual_3=pygal.Line(x_label_rotation=45)
    charts_individual_4=pygal.Line(x_label_rotation=45)
    #print (datetime.fromtimestamp(data['Data'][item]['time'])).strftime('%Y-%m-%d %H:%M:%S')
    #listcurr=[]
    #curr_0='BTC'
    #for a day fetch 48*5 rows
    for i in range(len(rows)-250,len(rows)):
        tupl= rows[i]
        var= tupl[2]
        if type(var)==float:
            if i%5==0 and tupl[0]==curr0:
                curr0_x_axis_data.append(tupl[2])
                curr0_y_axis_data.append(tupl[1])
                print i,tupl[0],":","x",tupl[2],"y",tupl[1]
            elif i%5==1 and tupl[0]==curr1:
                curr1_x_axis_data.append(tupl[2])
                curr1_y_axis_data.append(tupl[1])
                print i,tupl[0],":","x",tupl[2],"y",tupl[1]
            elif i%5==2 and tupl[0]==curr2:
                curr2_x_axis_data.append(tupl[2])
                curr2_y_axis_data.append(tupl[1])
                print i,tupl[0],":","x",tupl[2],"y",tupl[1]
            elif i%5==3 and tupl[0]==curr3:
                curr3_x_axis_data.append(tupl[2])
                curr3_y_axis_data.append(tupl[1])
                print i,tupl[0],":","x",tupl[2],"y",tupl[1]
            elif i%5==4 and tupl[0]==curr4:
                curr4_x_axis_data.append(tupl[2])
                curr4_y_axis_data.append(tupl[1])
                print i,tupl[0],":","x",tupl[2],"y",tupl[1]
            
    chart=pygal.Line(x_label_rotation=45)
    chart.x_labels=curr0_x_axis_data                #x axis labels of all are same ,ie same timestamps for all
    chart.add(curr0,curr0_y_axis_data)
    chart.add(curr1,curr1_y_axis_data)
    chart.add(curr2,curr2_y_axis_data)
    chart.add(curr3,curr3_y_axis_data)
    chart.add(curr4,curr4_y_axis_data)
    charts_individual_0.x_labels=curr0_x_axis_data  
    charts_individual_0.add(curr0,curr0_y_axis_data)
    charts_individual_1.x_labels=curr0_x_axis_data
    charts_individual_1.add(curr1,curr1_y_axis_data)
    charts_individual_2.x_labels=curr0_x_axis_data
    charts_individual_2.add(curr2,curr2_y_axis_data)
    charts_individual_3.x_labels=curr0_x_axis_data
    charts_individual_3.add(curr3,curr3_y_axis_data)
    charts_individual_4.x_labels=curr0_x_axis_data
    charts_individual_4.add(curr4,curr4_y_axis_data)
    #conn.commit()
    #conn.close()
    chart.render_to_file('static/images/Line_chart_comparison.svg')
    charts_individual_0.render_to_file('static/images/'+curr0+'.svg')
    charts_individual_1.render_to_file('static/images/'+curr1+'.svg')
    charts_individual_2.render_to_file('static/images/'+curr2+'.svg')
    charts_individual_3.render_to_file('static/images/'+curr3+'.svg')
    charts_individual_4.render_to_file('static/images/'+curr4+'.svg')
    img_url_comparison = 'static/images/Line_chart_comparison.svg?cache=' + str(time.time())
    #context={"url1":'static/images/BTC.svg?cache=' + str(time.time()),"url2":'static/images/ETH.svg?cache=' + str(time.time()),"url3":'static/images/LTC.svg?cache=' + str(time.time())}
    #return chart.render_response()  
    #img_url = ['static/images/'+curr0+'.svg?cache=' + str(time.time()),'static/images/'+curr1+'.svg?cache=' + str(time.time())]
    
    return render_template('app.html',image_url = img_url_comparison)

# %%
if (__name__ == "__main__"):
    hostname = 'baasu.db.elephantsql.com'
    username = 'dbuzkqmi'
    password = 'vi24qSFc5TG77k5GPa4aQr3XlnLOBIRf'
    database = 'dbuzkqmi'
    port='5432'
    conn = psycopg2.connect(host=hostname, user=username, password=password, dbname=database,port=port)
    #conn=connection()
    curr=conn.cursor()
    password ='12345'
    email='goyalakshita@gmail.com'
    name='Akshita'
    curr.execute("insert into public.user (password,email,name) values('{}','{}','{}')".format(password,email,name))
    cur=conn.cursor()
    app.run(debug=False)
# Out:
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [23/Mar/2018 17:54:12] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2018 17:54:12] "GET /favicon.ico HTTP/1.1" 404 -
# ('BTC', 'ETH', 'XRP', 'BCH', 'LTC')
# 51 ETH : x 695000.0 y 2000.0
# 52 XRP : x 695000.0 y 2000.0
# 53 BCH : x 695000.0 y 20000.0
# 54 LTC : x 695000.0 y 25000.0
# 55 BTC : x 1390000.0 y 48000.0
# 56 ETH : x 1390000.0 y 4000.0
# 57 XRP : x 1390000.0 y 4000.0
# 58 BCH : x 1390000.0 y 40000.0
# 59 LTC : x 1390000.0 y 50000.0
# 60 BTC : x 2085000.0 y 72000.0
# 61 ETH : x 2085000.0 y 6000.0
# 62 XRP : x 2085000.0 y 6000.0
# 63 BCH : x 2085000.0 y 60000.0
# 64 LTC : x 2085000.0 y 75000.0
# 65 BTC : x 2780000.0 y 96000.0
# 66 ETH : x 2780000.0 y 8000.0
# 67 XRP : x 2780000.0 y 8000.0
# 68 BCH : x 2780000.0 y 80000.0
# 69 LTC : x 2780000.0 y 100000.0
# 70 BTC : x 3475000.0 y 120000.0
# 71 ETH : x 3475000.0 y 10000.0
# 72 XRP : x 3475000.0 y 10000.0
# 73 BCH : x 3475000.0 y 100000.0
# 74 LTC : x 3475000.0 y 125000.0
# 75 BTC : x 4170000.0 y 144000.0
# 76 ETH : x 4170000.0 y 12000.0
# 77 XRP : x 4170000.0 y 12000.0
# 78 BCH : x 4170000.0 y 120000.0
# 79 LTC : x 4170000.0 y 150000.0
# 80 BTC : x 4865000.0 y 168000.0
# 81 ETH : x 4865000.0 y 14000.0
# 82 XRP : x 4865000.0 y 14000.0
# 83 BCH : x 4865000.0 y 140000.0
# 84 LTC : x 4865000.0 y 175000.0
# 85 BTC : x 5560000.0 y 192000.0
# 86 ETH : x 5560000.0 y 16000.0
# 87 XRP : x 5560000.0 y 16000.0
# 88 BCH : x 5560000.0 y 160000.0
# 89 LTC : x 5560000.0 y 200000.0
# 90 BTC : x 6255000.0 y 216000.0
# 91 ETH : x 6255000.0 y 18000.0
# 92 XRP : x 6255000.0 y 18000.0
# 93 BCH : x 6255000.0 y 180000.0
# 94 LTC : x 6255000.0 y 225000.0
# 95 BTC : x 6950000.0 y 240000.0
# 96 ETH : x 6950000.0 y 20000.0
# 97 XRP : x 6950000.0 y 20000.0
# 98 BCH : x 6950000.0 y 200000.0
# 99 LTC : x 6950000.0 y 250000.0
# 100 BTC : x 7645000.0 y 264000.0
# 101 ETH : x 7645000.0 y 22000.0
# 102 XRP : x 7645000.0 y 22000.0
# 103 BCH : x 7645000.0 y 220000.0
# 104 LTC : x 7645000.0 y 275000.0
# 105 BTC : x 8340000.0 y 288000.0
# 106 ETH : x 8340000.0 y 24000.0
# 107 XRP : x 8340000.0 y 24000.0
# 108 BCH : x 8340000.0 y 240000.0
# 109 LTC : x 8340000.0 y 300000.0
# 110 BTC : x 9035000.0 y 312000.0
# 111 ETH : x 9035000.0 y 26000.0
# 112 XRP : x 9035000.0 y 26000.0
# 113 BCH : x 9035000.0 y 260000.0
# 114 LTC : x 9035000.0 y 325000.0
# 115 BTC : x 9730000.0 y 336000.0
# 116 ETH : x 9730000.0 y 28000.0
# 117 XRP : x 9730000.0 y 28000.0
# 118 BCH : x 9730000.0 y 280000.0
# 119 LTC : x 9730000.0 y 350000.0
# 120 BTC : x 10425000.0 y 360000.0
# 121 ETH : x 10425000.0 y 30000.0
# 122 XRP : x 10425000.0 y 30000.0
# 123 BCH : x 10425000.0 y 300000.0
# 124 LTC : x 10425000.0 y 375000.0
# 125 BTC : x 11120000.0 y 384000.0
# 126 ETH : x 11120000.0 y 32000.0
# 127 XRP : x 11120000.0 y 32000.0
# 128 BCH : x 11120000.0 y 320000.0
# 129 LTC : x 11120000.0 y 400000.0
# 130 BTC : x 11815000.0 y 408000.0
# 131 ETH : x 11815000.0 y 34000.0
# 132 XRP : x 11815000.0 y 34000.0
# 133 BCH : x 11815000.0 y 340000.0
# 134 LTC : x 11815000.0 y 425000.0
# 135 BTC : x 12510000.0 y 432000.0
# 136 ETH : x 12510000.0 y 36000.0
# 137 XRP : x 12510000.0 y 36000.0
# 138 BCH : x 12510000.0 y 360000.0
# 139 LTC : x 12510000.0 y 450000.0
# 140 BTC : x 13205000.0 y 456000.0
# 141 ETH : x 13205000.0 y 38000.0
# 142 XRP : x 13205000.0 y 38000.0
# 143 BCH : x 13205000.0 y 380000.0
# 144 LTC : x 13205000.0 y 475000.0
# 145 BTC : x 13900000.0 y 480000.0
# 146 ETH : x 13900000.0 y 40000.0
# 147 XRP : x 13900000.0 y 40000.0
# 148 BCH : x 13900000.0 y 400000.0
# 149 LTC : x 13900000.0 y 500000.0
# 150 BTC : x 14595000.0 y 504000.0
# 151 ETH : x 14595000.0 y 42000.0
# 152 XRP : x 14595000.0 y 42000.0
# 153 BCH : x 14595000.0 y 420000.0
# 154 LTC : x 14595000.0 y 525000.0
# 155 BTC : x 15290000.0 y 528000.0
# 156 ETH : x 15290000.0 y 44000.0
# 157 XRP : x 15290000.0 y 44000.0
# 158 BCH : x 15290000.0 y 440000.0
# 159 LTC : x 15290000.0 y 550000.0
# 160 BTC : x 15985000.0 y 552000.0
# 161 ETH : x 15985000.0 y 46000.0
# 162 XRP : x 15985000.0 y 46000.0
# 163 BCH : x 15985000.0 y 460000.0
# 164 LTC : x 15985000.0 y 575000.0
# 165 BTC : x 16680000.0 y 576000.0
# 166 ETH : x 16680000.0 y 48000.0
# 167 XRP : x 16680000.0 y 48000.0
# 168 BCH : x 16680000.0 y 480000.0
# 169 LTC : x 16680000.0 y 600000.0
# 170 BTC : x 17375000.0 y 600000.0
# 171 ETH : x 17375000.0 y 50000.0
# 172 XRP : x 17375000.0 y 50000.0
# 173 BCH : x 17375000.0 y 500000.0
# 174 LTC : x 17375000.0 y 625000.0
# 175 BTC : x 18070000.0 y 624000.0
# 176 ETH : x 18070000.0 y 52000.0
# 177 XRP : x 18070000.0 y 52000.0
# 178 BCH : x 18070000.0 y 520000.0
# 179 LTC : x 18070000.0 y 650000.0
# 180 BTC : x 18765000.0 y 648000.0
# 181 ETH : x 18765000.0 y 54000.0
# 182 XRP : x 18765000.0 y 54000.0
# 183 BCH : x 18765000.0 y 540000.0
# 184 LTC : x 18765000.0 y 675000.0
# 185 BTC : x 19460000.0 y 672000.0
# 186 ETH : x 19460000.0 y 56000.0
# 187 XRP : x 19460000.0 y 56000.0
# 188 BCH : x 19460000.0 y 560000.0
# 189 LTC : x 19460000.0 y 700000.0
# 190 BTC : x 20155000.0 y 696000.0
# 191 ETH : x 20155000.0 y 58000.0
# 192 XRP : x 20155000.0 y 58000.0
# 193 BCH : x 20155000.0 y 580000.0
# 194 LTC : x 20155000.0 y 725000.0
# 195 BTC : x 20850000.0 y 720000.0
# 196 ETH : x 20850000.0 y 60000.0
# 197 XRP : x 20850000.0 y 60000.0
# 198 BCH : x 20850000.0 y 600000.0
# 199 LTC : x 20850000.0 y 750000.0
# 200 BTC : x 21545000.0 y 744000.0
# 201 ETH : x 21545000.0 y 62000.0
# 202 XRP : x 21545000.0 y 62000.0
# 203 BCH : x 21545000.0 y 620000.0
# 204 LTC : x 21545000.0 y 775000.0
# 205 BTC : x 22240000.0 y 768000.0
# 206 ETH : x 22240000.0 y 64000.0
# 207 XRP : x 22240000.0 y 64000.0
# 208 BCH : x 22240000.0 y 640000.0
# 209 LTC : x 22240000.0 y 800000.0
# 210 BTC : x 22935000.0 y 792000.0
# 211 ETH : x 22935000.0 y 66000.0
# 212 XRP : x 22935000.0 y 66000.0
# 213 BCH : x 22935000.0 y 660000.0
# 214 LTC : x 22935000.0 y 825000.0
# 215 BTC : x 23630000.0 y 816000.0
# 216 ETH : x 23630000.0 y 68000.0
# 217 XRP : x 23630000.0 y 68000.0
# 218 BCH : x 23630000.0 y 680000.0
# 219 LTC : x 23630000.0 y 850000.0
# 220 BTC : x 24325000.0 y 840000.0
# 221 ETH : x 24325000.0 y 70000.0
# 222 XRP : x 24325000.0 y 70000.0
# 223 BCH : x 24325000.0 y 700000.0
# 224 LTC : x 24325000.0 y 875000.0
# 225 BTC : x 25020000.0 y 864000.0
# 226 ETH : x 25020000.0 y 72000.0
# 227 XRP : x 25020000.0 y 72000.0
# 228 BCH : x 25020000.0 y 720000.0
# 229 LTC : x 25020000.0 y 900000.0
# 230 BTC : x 25715000.0 y 888000.0
# 231 ETH : x 25715000.0 y 74000.0
# 232 XRP : x 25715000.0 y 74000.0
# 233 BCH : x 25715000.0 y 740000.0
# 234 LTC : x 25715000.0 y 925000.0
# 235 BTC : x 26410000.0 y 912000.0
# 236 ETH : x 26410000.0 y 76000.0
# 237 XRP : x 26410000.0 y 76000.0
# 238 BCH : x 26410000.0 y 760000.0
# 239 LTC : x 26410000.0 y 950000.0
# 240 BTC : x 27105000.0 y 936000.0
# 241 ETH : x 27105000.0 y 78000.0
# 242 XRP : x 27105000.0 y 78000.0
# 243 BCH : x 27105000.0 y 780000.0
# 244 LTC : x 27105000.0 y 975000.0
# 245 BTC : x 27800000.0 y 960000.0
# 246 ETH : x 27800000.0 y 80000.0
# 247 XRP : x 27800000.0 y 80000.0
# 248 BCH : x 27800000.0 y 800000.0
# 249 LTC : x 27800000.0 y 1000000.0
# 250 BTC : x 28495000.0 y 984000.0
# 251 ETH : x 28495000.0 y 82000.0
# 252 XRP : x 28495000.0 y 82000.0
# 253 BCH : x 28495000.0 y 820000.0
# 254 LTC : x 28495000.0 y 1025000.0
# 255 BTC : x 29190000.0 y 1008000.0
# 256 ETH : x 29190000.0 y 84000.0
# 257 XRP : x 29190000.0 y 84000.0
# 258 BCH : x 29190000.0 y 840000.0
# 259 LTC : x 29190000.0 y 1050000.0
# 260 BTC : x 29885000.0 y 1032000.0
# 261 ETH : x 29885000.0 y 86000.0
# 262 XRP : x 29885000.0 y 86000.0
# 263 BCH : x 29885000.0 y 860000.0
# 264 LTC : x 29885000.0 y 1075000.0
# 265 BTC : x 30580000.0 y 1056000.0
# 266 ETH : x 30580000.0 y 88000.0
# 267 XRP : x 30580000.0 y 88000.0
# 268 BCH : x 30580000.0 y 880000.0
# 269 LTC : x 30580000.0 y 1100000.0
# 270 BTC : x 31275000.0 y 1080000.0
# 271 ETH : x 31275000.0 y 90000.0
# 272 XRP : x 31275000.0 y 90000.0
# 273 BCH : x 31275000.0 y 900000.0
# 274 LTC : x 31275000.0 y 1125000.0
# 275 BTC : x 31970000.0 y 1104000.0
# 276 ETH : x 31970000.0 y 92000.0
# 277 XRP : x 31970000.0 y 92000.0
# 278 BCH : x 31970000.0 y 920000.0
# 279 LTC : x 31970000.0 y 1150000.0
# 280 BTC : x 32665000.0 y 1128000.0
# 281 ETH : x 32665000.0 y 94000.0
# 282 XRP : x 32665000.0 y 94000.0
# 283 BCH : x 32665000.0 y 940000.0
# 284 LTC : x 32665000.0 y 1175000.0
# 285 BTC : x 33360000.0 y 1152000.0
# 286 ETH : x 33360000.0 y 96000.0
# 287 XRP : x 33360000.0 y 96000.0
# 288 BCH : x 33360000.0 y 960000.0
# 289 LTC : x 33360000.0 y 1200000.0
# 290 BTC : x 34055000.0 y 1176000.0
# 291 ETH : x 34055000.0 y 98000.0
# 292 XRP : x 34055000.0 y 98000.0
# 293 BCH : x 34055000.0 y 980000.0
# 294 LTC : x 34055000.0 y 1225000.0
# 295 BTC : x 34455000.0 y 99999999.0
# 127.0.0.1 - - [23/Mar/2018 17:54:18] "GET /AllGraphs HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Mar/2018 17:54:18] "GET /static/images/Line_chart_comparison.svg?cache=1521807858.69 HTTP/1.1" 200 -
